# %% [markdown]
# # Active contour segmentation pre-processing performance comparison

# %%
# Import libararies
import numpy as np
import matplotlib.pyplot as plt
import cv2
import utils
import lsm
from skimage import img_as_float
from scipy.ndimage.filters import gaussian_filter # For a Gaussian blur

# %% [markdown]
# ## Import data

# %%
# Get Data
data = utils.obtain_data("../../data/vessels")  # add your path here
train_data = data['train']
train_names = train_data['names']
train_images = train_data['images']
train_labels = train_data['labels']

# %% [markdown]
# ## Define hyperparameters

# %%
# Define the size
n1 = 1024
n2 = 1024

# Paramters for a level set method
rho = 1        # No need to modify this. It doesn't affect the result very much.
sigma   = 1e-7 # A parameter for a convolution. Higher the value, lesser the noise and lower the accuracy.
omega   = 0.2  # A ratio of gG and gL functions. gL + omega * gG.
epsilon = 0.2  # A paramter for a H_epsilon function.

# Run a method
max_iter = 600 # Maximum iterations
print_every = -1 # Verbose. Print every [print_every] iteration. It won't print out if -1
step_size = 500 # step size of the method

# %% [markdown]
# ## Comparison of Gaussian blur and Gaussian blur + contrast enhancement

# %%
def preprocess_img(img_index, sigma=1.0, clip_limit=4.0):
    image = train_images[img_index]
    image = cv2.resize(image, (n2, n1))  # Resizing to (n2,n1)
    label = train_labels[img_index]
    label = cv2.resize(label, (n2, n1))  # Resizing to (n2,n1)

    # Apply Gaussian blur
    gb_image = gaussian_filter(image, sigma=sigma)
    
    pr_image = utils.scale_to_uint(gb_image)
    
    # Improve contrast
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=(8, 8))
    pr_image = img_as_float(np.array(clahe.apply(np.expand_dims(pr_image, axis=-1))).squeeze())

    return image, gb_image, pr_image, label

# Just do first 4 images
for i in range(4):

    image, gb_image, pr_image, label = preprocess_img(i, sigma=1.5)
    
    segments = []
    
    for j, img in enumerate([gb_image, pr_image]):
        # Create a lsm object
        curr_lsm = lsm.LSM(n1, n2, rho, sigma, omega, epsilon)

        # Initialize based on center of mass using smoothing method
        curr_lsm.initialize_phi(image)

        # Run a method.
        phi = utils.run_lsm(img, curr_lsm, step_size=step_size, max_iter=max_iter, 
                            print_every=print_every, do_plot=False)
        
        # Obtain segmentation
        segment = np.zeros_like(image)
        segment[phi >= 0] = 1

        segments.append(segment)
        
    print("Image: {}".format(train_names[i]))
    fig, ax = plt.subplots(1, 4, figsize=(20, 5))
       
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title("Original Image")
    
    ax[1].imshow(segments[0], cmap='gray')
    ax[1].set_title("Gaussian blur")
    
    ax[2].imshow(segments[1], cmap='gray')
    ax[2].set_title("Gaussian blur + contrast enhancement")

    ax[3].imshow(label, 'gray')
    ax[3].set_title("Ground Truth")
    
    plt.tight_layout()
    plt.show()
# Out:
# Image: 52al.png
# Image: 53al.png
# Image: 53bf.png
# Image: 54bl.png
